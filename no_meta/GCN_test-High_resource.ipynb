# %%
import os
import torch
from torch.utils.data import Dataset
import numpy as np
import collections
import csv
import random
import pickle
from torch.utils.data import DataLoader
import dgl
import pandas as pd

class Subgraphs(Dataset):


    def __init__(self, root, mode, subgraph_list, subgraph2label, subgraph2center_node, nodes_aux, labels_aux):   

        self.subgraph2label = subgraph2label
        self.subgraph_list = subgraph_list
        self.subgraph2center_node = subgraph2center_node
        self.subgraph2nodes_aux  = nodes_aux
        self.subgraph2labels_aux  = labels_aux
        
        self.data = pd.read_csv(os.path.join(root, mode + '.csv'))  # csv path
    
    def __getitem__(self, index):
        
        return self.subgraph_list[self.data.iloc[index]['name']], self.subgraph2label[self.data.iloc[index]['name']], self.subgraph2center_node[self.data.iloc[index]['name']], self.subgraph2nodes_aux[self.data.iloc[index]['name']], self.subgraph2labels_aux[self.data.iloc[index]['name']]

    def __len__(self):
        # as we have built up to batchsz of sets, you can sample some small batch size of sets.
        return len(self.data)
    
def collate(samples):
    # The input `samples` is a list of pairs
    #  (graph, label).
    graphs, labels, center_nodes, nodes_auxill, labels_auxill = map(list, zip(*samples))
    batched_graph = dgl.batch(graphs)
    #print(nodes_auxill)
    #nodes_auxill = np.vstack(nodes_auxill)
    labels_auxill = np.hstack(labels_auxill)    
    return batched_graph, torch.LongTensor(labels), torch.LongTensor(center_nodes), nodes_auxill, torch.LongTensor(labels_auxill)

# %%
import dgl.function as fn
import torch
import torch.nn as nn


# Sends a message of node feature h.
msg = fn.copy_src(src='h', out='m')

def reduce(nodes):
    """Take an average over all neighbor node features hu and use it to
    overwrite the original node feature."""
    accum = torch.mean(nodes.mailbox['m'], 1)
    return {'h': accum}

class NodeApplyModule(nn.Module):
    """Update the node feature hv with ReLU(Whv+b)."""
    def __init__(self, in_feats, out_feats, activation):
        super(NodeApplyModule, self).__init__()
        self.linear = nn.Linear(in_feats, out_feats)
        self.activation = activation

    def forward(self, node):
        h = self.linear(node.data['h'])
        h = self.activation(h)
        return {'h' : h}

class GCN(nn.Module):
    def __init__(self, in_feats, out_feats, activation):
        super(GCN, self).__init__()
        self.apply_mod = NodeApplyModule(in_feats, out_feats, activation)

    def forward(self, g, feature):
        # Initialize the node features with h.
        g.ndata['h'] = feature
        g.update_all(msg, reduce)
        g.apply_nodes(func=self.apply_mod)
        return g.ndata.pop('h')

# %%
import torch.nn.functional as F


class Classifier(nn.Module):
    def __init__(self, in_dim, hidden_dim, n_classes):
        super(Classifier, self).__init__()

        self.layers = nn.ModuleList([
            GCN(in_dim, hidden_dim, F.relu),
            GCN(hidden_dim, hidden_dim, F.relu)])
        self.classify = nn.Linear(hidden_dim, n_classes)

    def forward(self, g, to_fetch_center, to_fetch_aux):
        # to_fetch_aux: [[idx1, .., idx_n1], [idx1, .., idx_n2], [idx1, .., idx_n3]]
        h = g.in_degrees().view(-1, 1).float().to(device)
        for conv in self.layers:
            h = conv(g, h)
        g.ndata['h'] = h
        #print(h.shape)
        #hg = dgl.mean_nodes(g, 'h')
        #print(to_fetch)
        num_nodes_ = g.batch_num_nodes
        num_nodes_.insert(0, 0)
        offset = torch.cumsum(torch.LongTensor(num_nodes_), dim = 0)[:-1].to(device)
        hg = h[to_fetch_center + offset]
        offset_aux = np.hstack([np.array([offset[i]] * len(ego)) + np.array(ego) for i, ego in enumerate(to_fetch_aux)])
        h_aux = h[offset_aux]
        #print(hg.shape)
        #print(hg.shape)
        #print(h[0].shape)
        #hg = h[g.nodes[0].data['center_node'].detach().numpy()[0]]
        #print(hg.shape)
        return self.classify(hg), self.classify(h_aux)

# %%
from torch.utils.data import DataLoader
import torch.optim as optim
dataset = 'cora'
path = '/n/scratch2/kexinhuang/MGNN_Data/cora/fold1/'
path = '../../MGNN_Local_Data/cora/'

with open(path + 'list_subgraph.pkl', 'rb') as f:
    total_subgraph = pickle.load(f)
    
with open(path + 'label.pkl', 'rb') as f:
    info = pickle.load(f)

with open(path + 'center.pkl', 'rb') as f:
    center_node = pickle.load(f)

with open(path + 'nodes_aux.pkl', 'rb') as f:
    nodes_aux = pickle.load(f)
    
with open(path + 'labels_aux.pkl', 'rb') as f:
    labels_aux = pickle.load(f)   
    
trainset = Subgraphs(path, 'train', total_subgraph, info, center_node, nodes_aux, labels_aux)
#valset = Subgraphs(path, mode='val', path_s = 'list_subgraph.pkl', path_l = 'label.pkl')
#testset = Subgraphs(path, mode='test', path_s = 'list_subgraph.pkl', path_l = 'label.pkl')
    
data_loader = DataLoader(trainset, batch_size=64, shuffle=True,
                         collate_fn=collate)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Create model
model = Classifier(1, 64, 10)
model.to(device)
loss_func = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
model.train()

epoch_losses = []
for epoch in range(500):
    epoch_loss = 0
    center_loss = 0
    aux_loss = 0
    for iter, (bg, label, to_fetch, to_fetch_aux, labels_aux) in enumerate(data_loader):
        bg = bg.to(device)
        label = label.to(device)
        labels_aux = labels_aux.to(device)
        prediction_center, prediction_aux = model(bg, to_fetch, to_fetch_aux)
        #print(prediction.shape)
        loss1 = loss_func(prediction_center, label)
        loss2 = loss_func(prediction_aux, labels_aux)
        loss = loss1 + loss2
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        epoch_loss += loss.detach().item()
        center_loss += loss1.detach().item()
        aux_loss += loss2.detach().item()

    epoch_loss /= (iter + 1)
    center_loss /= (iter + 1)
    aux_loss /= (iter + 1)
    
    print('Epoch {}, loss_center {:.4f}, loss_aux {:.4f}, loss {:.4f}'.format(epoch, center_loss, aux_loss, epoch_loss))
    epoch_losses.append(epoch_loss)
# Out:
# Epoch 0, loss_center 2.3450, loss_aux 2.5646, loss 4.9096
# Epoch 1, loss_center 2.0903, loss_aux 1.7203, loss 3.8105
# Epoch 2, loss_center 1.9727, loss_aux 1.6371, loss 3.6099
# Epoch 3, loss_center 1.8926, loss_aux 1.5713, loss 3.4639
# Epoch 4, loss_center 1.8414, loss_aux 1.5345, loss 3.3759
# Epoch 5, loss_center 1.8060, loss_aux 1.5000, loss 3.3060
# Epoch 6, loss_center 1.7845, loss_aux 1.4977, loss 3.2822
# Epoch 7, loss_center 1.7796, loss_aux 1.4818, loss 3.2614
# Epoch 8, loss_center 1.7692, loss_aux 1.4731, loss 3.2423
# Epoch 9, loss_center 1.7681, loss_aux 1.4682, loss 3.2363
# Epoch 10, loss_center 1.7621, loss_aux 1.4638, loss 3.2259
# Epoch 11, loss_center 1.7590, loss_aux 1.4636, loss 3.2227
# Epoch 12, loss_center 1.7583, loss_aux 1.4629, loss 3.2212
# Epoch 13, loss_center 1.7583, loss_aux 1.4595, loss 3.2178
# Epoch 14, loss_center 1.7541, loss_aux 1.4611, loss 3.2153
# Epoch 15, loss_center 1.7579, loss_aux 1.4588, loss 3.2166
# Epoch 16, loss_center 1.7569, loss_aux 1.4541, loss 3.2111
# Epoch 17, loss_center 1.7518, loss_aux 1.4487, loss 3.2005
# Epoch 18, loss_center 1.7529, loss_aux 1.4670, loss 3.2199
# Epoch 19, loss_center 1.7548, loss_aux 1.4467, loss 3.2016
# Epoch 20, loss_center 1.7548, loss_aux 1.4651, loss 3.2200
# Epoch 21, loss_center 1.7501, loss_aux 1.4486, loss 3.1987
# Epoch 22, loss_center 1.7579, loss_aux 1.4673, loss 3.2252
# Epoch 23, loss_center 1.7508, loss_aux 1.4451, loss 3.1959
# Epoch 24, loss_center 1.7534, loss_aux 1.4471, loss 3.2005
# Epoch 25, loss_center 1.7485, loss_aux 1.4382, loss 3.1866
# Epoch 26, loss_center 1.7510, loss_aux 1.4375, loss 3.1885
# Epoch 27, loss_center 1.7477, loss_aux 1.4403, loss 3.1880
# Epoch 28, loss_center 1.7485, loss_aux 1.4395, loss 3.1880
# Epoch 29, loss_center 1.7485, loss_aux 1.4427, loss 3.1913
# Epoch 30, loss_center 1.7519, loss_aux 1.4436, loss 3.1955
# Epoch 31, loss_center 1.7444, loss_aux 1.4416, loss 3.1859
# Epoch 32, loss_center 1.7460, loss_aux 1.4346, loss 3.1806
# Epoch 33, loss_center 1.7458, loss_aux 1.4235, loss 3.1693
# Epoch 34, loss_center 1.7480, loss_aux 1.4278, loss 3.1758
# Epoch 35, loss_center 1.7512, loss_aux 1.4436, loss 3.1948
# Epoch 36, loss_center 1.7453, loss_aux 1.4354, loss 3.1808
# Epoch 37, loss_center 1.7429, loss_aux 1.4315, loss 3.1744
# Epoch 38, loss_center 1.7422, loss_aux 1.4424, loss 3.1846
# Epoch 39, loss_center 1.7420, loss_aux 1.4407, loss 3.1827
# Epoch 40, loss_center 1.7465, loss_aux 1.4469, loss 3.1934
# Epoch 41, loss_center 1.7446, loss_aux 1.4299, loss 3.1745
# Epoch 42, loss_center 1.7427, loss_aux 1.4218, loss 3.1645
# Epoch 43, loss_center 1.7427, loss_aux 1.4227, loss 3.1654
# Epoch 44, loss_center 1.7439, loss_aux 1.4257, loss 3.1697
# Epoch 45, loss_center 1.7424, loss_aux 1.4322, loss 3.1745
# Epoch 46, loss_center 1.7411, loss_aux 1.4160, loss 3.1571
# Epoch 47, loss_center 1.7435, loss_aux 1.4217, loss 3.1652
# Epoch 48, loss_center 1.7430, loss_aux 1.4267, loss 3.1697
# Epoch 49, loss_center 1.7400, loss_aux 1.4166, loss 3.1565
# Epoch 50, loss_center 1.7398, loss_aux 1.4403, loss 3.1801
# Epoch 51, loss_center 1.7388, loss_aux 1.4157, loss 3.1545
# Epoch 52, loss_center 1.7388, loss_aux 1.4195, loss 3.1583
# Epoch 53, loss_center 1.7368, loss_aux 1.4122, loss 3.1491
# Epoch 54, loss_center 1.7386, loss_aux 1.4089, loss 3.1475
# Epoch 55, loss_center 1.7353, loss_aux 1.4040, loss 3.1393
# Epoch 56, loss_center 1.7357, loss_aux 1.4040, loss 3.1397
# Epoch 57, loss_center 1.7368, loss_aux 1.3997, loss 3.1365
# Epoch 58, loss_center 1.7344, loss_aux 1.4094, loss 3.1438
# Epoch 59, loss_center 1.7354, loss_aux 1.4071, loss 3.1425
# Epoch 60, loss_center 1.7356, loss_aux 1.4134, loss 3.1490
# Epoch 61, loss_center 1.7347, loss_aux 1.4077, loss 3.1424
# Epoch 62, loss_center 1.7335, loss_aux 1.4171, loss 3.1506
# Epoch 63, loss_center 1.7392, loss_aux 1.4099, loss 3.1491
# Epoch 64, loss_center 1.7387, loss_aux 1.4054, loss 3.1440
# Epoch 65, loss_center 1.7333, loss_aux 1.4003, loss 3.1336
# Epoch 66, loss_center 1.7362, loss_aux 1.3893, loss 3.1256
# Epoch 67, loss_center 1.7307, loss_aux 1.3948, loss 3.1255
# Epoch 68, loss_center 1.7307, loss_aux 1.3860, loss 3.1167
# Epoch 69, loss_center 1.7355, loss_aux 1.3909, loss 3.1265
# Epoch 70, loss_center 1.7349, loss_aux 1.3853, loss 3.1201
# Epoch 71, loss_center 1.7337, loss_aux 1.4016, loss 3.1352
# Epoch 72, loss_center 1.7339, loss_aux 1.4015, loss 3.1354
# Epoch 73, loss_center 1.7326, loss_aux 1.4106, loss 3.1432
# Epoch 74, loss_center 1.7330, loss_aux 1.4138, loss 3.1468
# Epoch 75, loss_center 1.7325, loss_aux 1.3931, loss 3.1256
# Epoch 76, loss_center 1.7287, loss_aux 1.3771, loss 3.1058
# Epoch 77, loss_center 1.7288, loss_aux 1.3836, loss 3.1124
# Epoch 78, loss_center 1.7337, loss_aux 1.3908, loss 3.1245
# Epoch 79, loss_center 1.7338, loss_aux 1.3887, loss 3.1225
# Epoch 80, loss_center 1.7273, loss_aux 1.3820, loss 3.1093
# Epoch 81, loss_center 1.7314, loss_aux 1.3831, loss 3.1145
# Epoch 82, loss_center 1.7287, loss_aux 1.3777, loss 3.1064
# Epoch 83, loss_center 1.7268, loss_aux 1.3781, loss 3.1048
# Epoch 84, loss_center 1.7274, loss_aux 1.3748, loss 3.1022
# Epoch 85, loss_center 1.7281, loss_aux 1.3788, loss 3.1068
# Epoch 86, loss_center 1.7269, loss_aux 1.3792, loss 3.1061
# Epoch 87, loss_center 1.7284, loss_aux 1.3917, loss 3.1200
# Epoch 88, loss_center 1.7327, loss_aux 1.3930, loss 3.1257
# Epoch 89, loss_center 1.7276, loss_aux 1.3891, loss 3.1167
# Epoch 90, loss_center 1.7268, loss_aux 1.3755, loss 3.1024
# Epoch 91, loss_center 1.7239, loss_aux 1.3735, loss 3.0974
# Epoch 92, loss_center 1.7251, loss_aux 1.3718, loss 3.0969
# Epoch 93, loss_center 1.7233, loss_aux 1.3666, loss 3.0899
# Epoch 94, loss_center 1.7239, loss_aux 1.3726, loss 3.0965
# Epoch 95, loss_center 1.7259, loss_aux 1.3726, loss 3.0985
# Epoch 96, loss_center 1.7289, loss_aux 1.3747, loss 3.1036
# Epoch 97, loss_center 1.7271, loss_aux 1.3809, loss 3.1081
# Epoch 98, loss_center 1.7235, loss_aux 1.3650, loss 3.0885
# Epoch 99, loss_center 1.7212, loss_aux 1.3616, loss 3.0829
# Epoch 100, loss_center 1.7252, loss_aux 1.3642, loss 3.0894
# Epoch 101, loss_center 1.7233, loss_aux 1.3670, loss 3.0903
# Epoch 102, loss_center 1.7244, loss_aux 1.3676, loss 3.0920
# Epoch 103, loss_center 1.7280, loss_aux 1.3772, loss 3.1052
# Epoch 104, loss_center 1.7240, loss_aux 1.3671, loss 3.0912
# Epoch 105, loss_center 1.7218, loss_aux 1.3710, loss 3.0929
# Epoch 106, loss_center 1.7243, loss_aux 1.3573, loss 3.0816
# Epoch 107, loss_center 1.7208, loss_aux 1.3644, loss 3.0851
# Epoch 108, loss_center 1.7202, loss_aux 1.3680, loss 3.0882
# Epoch 109, loss_center 1.7216, loss_aux 1.3554, loss 3.0770
# Epoch 110, loss_center 1.7227, loss_aux 1.3559, loss 3.0786
# Epoch 111, loss_center 1.7209, loss_aux 1.3685, loss 3.0894
# Epoch 112, loss_center 1.7215, loss_aux 1.3711, loss 3.0926
# Epoch 113, loss_center 1.7214, loss_aux 1.3533, loss 3.0748
# Epoch 114, loss_center 1.7255, loss_aux 1.3737, loss 3.0992
# Epoch 115, loss_center 1.7275, loss_aux 1.3641, loss 3.0917
# Epoch 116, loss_center 1.7207, loss_aux 1.3605, loss 3.0812
# Epoch 117, loss_center 1.7182, loss_aux 1.3680, loss 3.0862
# Epoch 118, loss_center 1.7199, loss_aux 1.3602, loss 3.0801
# Epoch 119, loss_center 1.7219, loss_aux 1.3631, loss 3.0850
# Epoch 120, loss_center 1.7189, loss_aux 1.3668, loss 3.0856
# Epoch 121, loss_center 1.7229, loss_aux 1.3772, loss 3.1000
# Epoch 122, loss_center 1.7173, loss_aux 1.3629, loss 3.0802
# Epoch 123, loss_center 1.7229, loss_aux 1.3648, loss 3.0877
# Epoch 124, loss_center 1.7164, loss_aux 1.3633, loss 3.0797
# Epoch 125, loss_center 1.7190, loss_aux 1.3537, loss 3.0727
# Epoch 126, loss_center 1.7182, loss_aux 1.3590, loss 3.0772
# Epoch 127, loss_center 1.7201, loss_aux 1.3680, loss 3.0882
# Epoch 128, loss_center 1.7195, loss_aux 1.3522, loss 3.0717
# Epoch 129, loss_center 1.7172, loss_aux 1.3461, loss 3.0632
# Epoch 130, loss_center 1.7196, loss_aux 1.3507, loss 3.0703
# Epoch 131, loss_center 1.7202, loss_aux 1.3504, loss 3.0705
# Epoch 132, loss_center 1.7173, loss_aux 1.3712, loss 3.0885
# Epoch 133, loss_center 1.7217, loss_aux 1.3712, loss 3.0929
# Epoch 134, loss_center 1.7184, loss_aux 1.3593, loss 3.0777
# Epoch 135, loss_center 1.7231, loss_aux 1.3637, loss 3.0868
# Epoch 136, loss_center 1.7169, loss_aux 1.3549, loss 3.0717
# Epoch 137, loss_center 1.7175, loss_aux 1.3469, loss 3.0644
# Epoch 138, loss_center 1.7182, loss_aux 1.3469, loss 3.0650
# Epoch 139, loss_center 1.7203, loss_aux 1.3478, loss 3.0681
# Epoch 140, loss_center 1.7193, loss_aux 1.3584, loss 3.0777
# Epoch 141, loss_center 1.7166, loss_aux 1.3539, loss 3.0705
# Epoch 142, loss_center 1.7164, loss_aux 1.3500, loss 3.0664
# Epoch 143, loss_center 1.7163, loss_aux 1.3537, loss 3.0700
# Epoch 144, loss_center 1.7185, loss_aux 1.3524, loss 3.0708
# Epoch 145, loss_center 1.7194, loss_aux 1.3490, loss 3.0684
# Epoch 146, loss_center 1.7183, loss_aux 1.3499, loss 3.0681
# Epoch 147, loss_center 1.7231, loss_aux 1.3578, loss 3.0810
# Epoch 148, loss_center 1.7148, loss_aux 1.3642, loss 3.0790
# Epoch 149, loss_center 1.7185, loss_aux 1.3463, loss 3.0648
# Epoch 150, loss_center 1.7155, loss_aux 1.3416, loss 3.0570
# Epoch 151, loss_center 1.7169, loss_aux 1.3380, loss 3.0549
# Epoch 152, loss_center 1.7160, loss_aux 1.3534, loss 3.0694
# Epoch 153, loss_center 1.7224, loss_aux 1.3590, loss 3.0815
# Epoch 154, loss_center 1.7173, loss_aux 1.3685, loss 3.0858
# Epoch 155, loss_center 1.7132, loss_aux 1.3492, loss 3.0624
# Epoch 156, loss_center 1.7180, loss_aux 1.3479, loss 3.0659
# Epoch 157, loss_center 1.7152, loss_aux 1.3483, loss 3.0635
# Epoch 158, loss_center 1.7134, loss_aux 1.3364, loss 3.0498
# Epoch 159, loss_center 1.7135, loss_aux 1.3401, loss 3.0536
# Epoch 160, loss_center 1.7155, loss_aux 1.3450, loss 3.0605
# Epoch 161, loss_center 1.7164, loss_aux 1.3413, loss 3.0577
# Epoch 162, loss_center 1.7140, loss_aux 1.3460, loss 3.0600
# Epoch 163, loss_center 1.7136, loss_aux 1.3455, loss 3.0590
# Epoch 164, loss_center 1.7191, loss_aux 1.3405, loss 3.0596
# Epoch 165, loss_center 1.7143, loss_aux 1.3468, loss 3.0611
# Epoch 166, loss_center 1.7177, loss_aux 1.3471, loss 3.0647
# Epoch 167, loss_center 1.7149, loss_aux 1.3437, loss 3.0586
# Epoch 168, loss_center 1.7189, loss_aux 1.3531, loss 3.0720
# Epoch 169, loss_center 1.7156, loss_aux 1.3528, loss 3.0684
# Epoch 170, loss_center 1.7125, loss_aux 1.3454, loss 3.0579
# Epoch 171, loss_center 1.7158, loss_aux 1.3448, loss 3.0606
# Epoch 172, loss_center 1.7161, loss_aux 1.3451, loss 3.0612
# Epoch 173, loss_center 1.7144, loss_aux 1.3380, loss 3.0524
# Epoch 174, loss_center 1.7156, loss_aux 1.3449, loss 3.0605
# Epoch 175, loss_center 1.7149, loss_aux 1.3448, loss 3.0597
# Epoch 176, loss_center 1.7182, loss_aux 1.3482, loss 3.0665
# Epoch 177, loss_center 1.7125, loss_aux 1.3570, loss 3.0695
# Epoch 178, loss_center 1.7142, loss_aux 1.3366, loss 3.0508
# Epoch 179, loss_center 1.7151, loss_aux 1.3400, loss 3.0551
# Epoch 180, loss_center 1.7139, loss_aux 1.3378, loss 3.0518
# Epoch 181, loss_center 1.7129, loss_aux 1.3410, loss 3.0539
# Epoch 182, loss_center 1.7184, loss_aux 1.3520, loss 3.0704
# Epoch 183, loss_center 1.7151, loss_aux 1.3391, loss 3.0542
# Epoch 184, loss_center 1.7151, loss_aux 1.3411, loss 3.0562
# Epoch 185, loss_center 1.7127, loss_aux 1.3438, loss 3.0565
# Epoch 186, loss_center 1.7187, loss_aux 1.3434, loss 3.0621
# Epoch 187, loss_center 1.7162, loss_aux 1.3451, loss 3.0613
# Epoch 188, loss_center 1.7120, loss_aux 1.3419, loss 3.0540
# Epoch 189, loss_center 1.7113, loss_aux 1.3365, loss 3.0478
# Epoch 190, loss_center 1.7148, loss_aux 1.3510, loss 3.0658
# Epoch 191, loss_center 1.7185, loss_aux 1.3530, loss 3.0716
# Epoch 192, loss_center 1.7129, loss_aux 1.3326, loss 3.0455
# Epoch 193, loss_center 1.7151, loss_aux 1.3457, loss 3.0608
# Epoch 194, loss_center 1.7145, loss_aux 1.3376, loss 3.0522
# Epoch 195, loss_center 1.7144, loss_aux 1.3461, loss 3.0605
# Epoch 196, loss_center 1.7127, loss_aux 1.3347, loss 3.0473
# Epoch 197, loss_center 1.7134, loss_aux 1.3359, loss 3.0493
# Epoch 198, loss_center 1.7176, loss_aux 1.3482, loss 3.0658
# Epoch 199, loss_center 1.7132, loss_aux 1.3349, loss 3.0480
# Epoch 200, loss_center 1.7153, loss_aux 1.3275, loss 3.0428
# Epoch 201, loss_center 1.7132, loss_aux 1.3373, loss 3.0505
# Epoch 202, loss_center 1.7133, loss_aux 1.3460, loss 3.0593
# Epoch 203, loss_center 1.7122, loss_aux 1.3383, loss 3.0506
# Epoch 204, loss_center 1.7156, loss_aux 1.3427, loss 3.0582
# Epoch 205, loss_center 1.7136, loss_aux 1.3374, loss 3.0510
# Epoch 206, loss_center 1.7108, loss_aux 1.3318, loss 3.0426
# Epoch 207, loss_center 1.7121, loss_aux 1.3455, loss 3.0576
# Epoch 208, loss_center 1.7109, loss_aux 1.3381, loss 3.0490
# Epoch 209, loss_center 1.7134, loss_aux 1.3334, loss 3.0468
# Epoch 210, loss_center 1.7147, loss_aux 1.3338, loss 3.0485
# Epoch 211, loss_center 1.7156, loss_aux 1.3358, loss 3.0514
# Epoch 212, loss_center 1.7135, loss_aux 1.3388, loss 3.0523
# Epoch 213, loss_center 1.7097, loss_aux 1.3466, loss 3.0564
# Epoch 214, loss_center 1.7156, loss_aux 1.3422, loss 3.0578
# Epoch 215, loss_center 1.7148, loss_aux 1.3438, loss 3.0586
# Epoch 216, loss_center 1.7171, loss_aux 1.3542, loss 3.0713
# Epoch 217, loss_center 1.7106, loss_aux 1.3273, loss 3.0379
# Epoch 218, loss_center 1.7125, loss_aux 1.3288, loss 3.0413
# Epoch 219, loss_center 1.7117, loss_aux 1.3266, loss 3.0383
# Epoch 220, loss_center 1.7120, loss_aux 1.3294, loss 3.0413
# Epoch 221, loss_center 1.7111, loss_aux 1.3203, loss 3.0314
# Epoch 222, loss_center 1.7142, loss_aux 1.3269, loss 3.0411
# Epoch 223, loss_center 1.7133, loss_aux 1.3518, loss 3.0651
# Epoch 224, loss_center 1.7123, loss_aux 1.3393, loss 3.0516
# Epoch 225, loss_center 1.7143, loss_aux 1.3536, loss 3.0678
# Epoch 226, loss_center 1.7144, loss_aux 1.3412, loss 3.0556
# Epoch 227, loss_center 1.7124, loss_aux 1.3377, loss 3.0501
# Epoch 228, loss_center 1.7091, loss_aux 1.3326, loss 3.0417
# Epoch 229, loss_center 1.7120, loss_aux 1.3383, loss 3.0503
# Epoch 230, loss_center 1.7168, loss_aux 1.3380, loss 3.0548
# Epoch 231, loss_center 1.7175, loss_aux 1.3410, loss 3.0585
# Epoch 232, loss_center 1.7113, loss_aux 1.3407, loss 3.0519
# Epoch 233, loss_center 1.7174, loss_aux 1.3414, loss 3.0588
# Epoch 234, loss_center 1.7149, loss_aux 1.3363, loss 3.0512
# Epoch 235, loss_center 1.7130, loss_aux 1.3285, loss 3.0415
# Epoch 236, loss_center 1.7118, loss_aux 1.3345, loss 3.0463
# Epoch 237, loss_center 1.7093, loss_aux 1.3277, loss 3.0370
# Epoch 238, loss_center 1.7114, loss_aux 1.3378, loss 3.0492
# Epoch 239, loss_center 1.7122, loss_aux 1.3275, loss 3.0397
# Epoch 240, loss_center 1.7092, loss_aux 1.3332, loss 3.0424
# Epoch 241, loss_center 1.7108, loss_aux 1.3348, loss 3.0456
# Epoch 242, loss_center 1.7142, loss_aux 1.3199, loss 3.0340
# Epoch 243, loss_center 1.7136, loss_aux 1.3405, loss 3.0541
# Epoch 244, loss_center 1.7096, loss_aux 1.3249, loss 3.0345
# Epoch 245, loss_center 1.7118, loss_aux 1.3337, loss 3.0455
# Epoch 246, loss_center 1.7087, loss_aux 1.3225, loss 3.0312
# Epoch 247, loss_center 1.7131, loss_aux 1.3322, loss 3.0453
# Epoch 248, loss_center 1.7081, loss_aux 1.3282, loss 3.0364
# Epoch 249, loss_center 1.7115, loss_aux 1.3264, loss 3.0379
# Epoch 250, loss_center 1.7105, loss_aux 1.3380, loss 3.0485
# Epoch 251, loss_center 1.7115, loss_aux 1.3225, loss 3.0340
# Epoch 252, loss_center 1.7114, loss_aux 1.3384, loss 3.0498
# Epoch 253, loss_center 1.7140, loss_aux 1.3171, loss 3.0311
# Epoch 254, loss_center 1.7155, loss_aux 1.3418, loss 3.0572
# Epoch 255, loss_center 1.7119, loss_aux 1.3299, loss 3.0417
# Epoch 256, loss_center 1.7152, loss_aux 1.3205, loss 3.0357
# Epoch 257, loss_center 1.7108, loss_aux 1.3257, loss 3.0366
# Epoch 258, loss_center 1.7152, loss_aux 1.3409, loss 3.0561
# Epoch 259, loss_center 1.7107, loss_aux 1.3292, loss 3.0398
# Epoch 260, loss_center 1.7133, loss_aux 1.3319, loss 3.0452
# Epoch 261, loss_center 1.7105, loss_aux 1.3211, loss 3.0315
# Epoch 262, loss_center 1.7102, loss_aux 1.3243, loss 3.0345
# Epoch 263, loss_center 1.7153, loss_aux 1.3231, loss 3.0384
# Epoch 264, loss_center 1.7090, loss_aux 1.3365, loss 3.0456
# Epoch 265, loss_center 1.7104, loss_aux 1.3359, loss 3.0463
# Epoch 266, loss_center 1.7123, loss_aux 1.3318, loss 3.0441
# Epoch 267, loss_center 1.7096, loss_aux 1.3214, loss 3.0311
# Epoch 268, loss_center 1.7105, loss_aux 1.3251, loss 3.0357
# Epoch 269, loss_center 1.7095, loss_aux 1.3378, loss 3.0472
# Epoch 270, loss_center 1.7079, loss_aux 1.3167, loss 3.0247
# Epoch 271, loss_center 1.7104, loss_aux 1.3283, loss 3.0387
# Epoch 272, loss_center 1.7090, loss_aux 1.3289, loss 3.0380
# Epoch 273, loss_center 1.7101, loss_aux 1.3212, loss 3.0313
# Epoch 274, loss_center 1.7093, loss_aux 1.3308, loss 3.0401
# Epoch 275, loss_center 1.7098, loss_aux 1.3160, loss 3.0258
# Epoch 276, loss_center 1.7143, loss_aux 1.3323, loss 3.0466
# Epoch 277, loss_center 1.7082, loss_aux 1.3324, loss 3.0406
# Epoch 278, loss_center 1.7102, loss_aux 1.3269, loss 3.0371
# Epoch 279, loss_center 1.7069, loss_aux 1.3234, loss 3.0303
# Epoch 280, loss_center 1.7109, loss_aux 1.3336, loss 3.0444
# Epoch 281, loss_center 1.7088, loss_aux 1.3194, loss 3.0283
# Epoch 282, loss_center 1.7088, loss_aux 1.3206, loss 3.0294
# Epoch 283, loss_center 1.7070, loss_aux 1.3262, loss 3.0332
# Epoch 284, loss_center 1.7102, loss_aux 1.3190, loss 3.0293
# Epoch 285, loss_center 1.7122, loss_aux 1.3282, loss 3.0404
# Epoch 286, loss_center 1.7140, loss_aux 1.3454, loss 3.0594
# Epoch 287, loss_center 1.7115, loss_aux 1.3123, loss 3.0237
# Epoch 288, loss_center 1.7109, loss_aux 1.3226, loss 3.0335
# Epoch 289, loss_center 1.7084, loss_aux 1.3129, loss 3.0213
# Epoch 290, loss_center 1.7125, loss_aux 1.3318, loss 3.0443
# Epoch 291, loss_center 1.7106, loss_aux 1.3266, loss 3.0372
# Epoch 292, loss_center 1.7094, loss_aux 1.3139, loss 3.0233
# Epoch 293, loss_center 1.7066, loss_aux 1.3224, loss 3.0289
# Epoch 294, loss_center 1.7130, loss_aux 1.3405, loss 3.0535
# Epoch 295, loss_center 1.7074, loss_aux 1.3171, loss 3.0245
# Epoch 296, loss_center 1.7135, loss_aux 1.3239, loss 3.0374
# Epoch 297, loss_center 1.7062, loss_aux 1.3107, loss 3.0170
# Epoch 298, loss_center 1.7113, loss_aux 1.3134, loss 3.0248
# Epoch 299, loss_center 1.7124, loss_aux 1.3381, loss 3.0506
# Epoch 300, loss_center 1.7109, loss_aux 1.3440, loss 3.0549
# Epoch 301, loss_center 1.7081, loss_aux 1.3077, loss 3.0158
# Epoch 302, loss_center 1.7071, loss_aux 1.3122, loss 3.0193
# Epoch 303, loss_center 1.7071, loss_aux 1.3046, loss 3.0117
# Epoch 304, loss_center 1.7101, loss_aux 1.3127, loss 3.0227
# Epoch 305, loss_center 1.7081, loss_aux 1.3177, loss 3.0259
# Epoch 306, loss_center 1.7079, loss_aux 1.3176, loss 3.0255
# Epoch 307, loss_center 1.7120, loss_aux 1.3227, loss 3.0347
# Epoch 308, loss_center 1.7140, loss_aux 1.3304, loss 3.0443
# Epoch 309, loss_center 1.7087, loss_aux 1.3244, loss 3.0332
# Epoch 310, loss_center 1.7063, loss_aux 1.3196, loss 3.0259
# Epoch 311, loss_center 1.7066, loss_aux 1.3087, loss 3.0153
# Epoch 312, loss_center 1.7081, loss_aux 1.3205, loss 3.0287
# Epoch 313, loss_center 1.7072, loss_aux 1.3111, loss 3.0183
# Epoch 314, loss_center 1.7077, loss_aux 1.3254, loss 3.0331
# Epoch 315, loss_center 1.7094, loss_aux 1.3133, loss 3.0226
# Epoch 316, loss_center 1.7075, loss_aux 1.3261, loss 3.0336
# Epoch 317, loss_center 1.7089, loss_aux 1.3221, loss 3.0310
# Epoch 318, loss_center 1.7069, loss_aux 1.3276, loss 3.0344
# Epoch 319, loss_center 1.7067, loss_aux 1.3182, loss 3.0249
# Epoch 320, loss_center 1.7092, loss_aux 1.3129, loss 3.0221
# Epoch 321, loss_center 1.7068, loss_aux 1.3103, loss 3.0171
# Epoch 322, loss_center 1.7059, loss_aux 1.3093, loss 3.0152
# Epoch 323, loss_center 1.7072, loss_aux 1.3096, loss 3.0168
# Epoch 324, loss_center 1.7082, loss_aux 1.3138, loss 3.0219
# Epoch 325, loss_center 1.7102, loss_aux 1.3056, loss 3.0158
# Epoch 326, loss_center 1.7065, loss_aux 1.3184, loss 3.0249
# Epoch 327, loss_center 1.7094, loss_aux 1.3173, loss 3.0267
# Epoch 328, loss_center 1.7104, loss_aux 1.3197, loss 3.0301
# Epoch 329, loss_center 1.7080, loss_aux 1.3257, loss 3.0337
# Epoch 330, loss_center 1.7111, loss_aux 1.3111, loss 3.0221
# Epoch 331, loss_center 1.7054, loss_aux 1.3218, loss 3.0272
# Epoch 332, loss_center 1.7052, loss_aux 1.3243, loss 3.0296
# Epoch 333, loss_center 1.7057, loss_aux 1.3050, loss 3.0106
# Epoch 334, loss_center 1.7053, loss_aux 1.3076, loss 3.0128
# Epoch 335, loss_center 1.7069, loss_aux 1.3161, loss 3.0229
# Epoch 336, loss_center 1.7058, loss_aux 1.3176, loss 3.0234
# Epoch 337, loss_center 1.7099, loss_aux 1.3167, loss 3.0266
# Epoch 338, loss_center 1.7045, loss_aux 1.3102, loss 3.0147
# Epoch 339, loss_center 1.7065, loss_aux 1.3123, loss 3.0188
# Epoch 340, loss_center 1.7060, loss_aux 1.3184, loss 3.0244
# Epoch 341, loss_center 1.7118, loss_aux 1.3089, loss 3.0207
# Epoch 342, loss_center 1.7059, loss_aux 1.3055, loss 3.0114
# Epoch 343, loss_center 1.7113, loss_aux 1.3056, loss 3.0169
# Epoch 344, loss_center 1.7028, loss_aux 1.3165, loss 3.0193
# Epoch 345, loss_center 1.7054, loss_aux 1.3111, loss 3.0165
# Epoch 346, loss_center 1.7082, loss_aux 1.2990, loss 3.0072
# Epoch 347, loss_center 1.7051, loss_aux 1.3088, loss 3.0140
# Epoch 348, loss_center 1.7050, loss_aux 1.3049, loss 3.0099
# Epoch 349, loss_center 1.7028, loss_aux 1.3155, loss 3.0183
# Epoch 350, loss_center 1.7057, loss_aux 1.3025, loss 3.0082
# Epoch 351, loss_center 1.7062, loss_aux 1.3144, loss 3.0207
# Epoch 352, loss_center 1.7038, loss_aux 1.3127, loss 3.0166
# Epoch 353, loss_center 1.7079, loss_aux 1.3150, loss 3.0229
# Epoch 354, loss_center 1.7093, loss_aux 1.3156, loss 3.0249
# Epoch 355, loss_center 1.7068, loss_aux 1.3228, loss 3.0296
# Epoch 356, loss_center 1.7084, loss_aux 1.3215, loss 3.0299
# Epoch 357, loss_center 1.7055, loss_aux 1.3172, loss 3.0227
# Epoch 358, loss_center 1.7075, loss_aux 1.3083, loss 3.0158
# Epoch 359, loss_center 1.7103, loss_aux 1.3272, loss 3.0375
# Epoch 360, loss_center 1.7084, loss_aux 1.3105, loss 3.0189
# Epoch 361, loss_center 1.7076, loss_aux 1.3228, loss 3.0304
# Epoch 362, loss_center 1.7083, loss_aux 1.3305, loss 3.0388
# Epoch 363, loss_center 1.7067, loss_aux 1.3250, loss 3.0317
# Epoch 364, loss_center 1.7057, loss_aux 1.3176, loss 3.0233
# Epoch 365, loss_center 1.7045, loss_aux 1.3170, loss 3.0216
# Epoch 366, loss_center 1.7056, loss_aux 1.3147, loss 3.0203
# Epoch 367, loss_center 1.7061, loss_aux 1.3146, loss 3.0207
# Epoch 368, loss_center 1.7076, loss_aux 1.3149, loss 3.0225
# Epoch 369, loss_center 1.7033, loss_aux 1.3014, loss 3.0048
# Epoch 370, loss_center 1.7064, loss_aux 1.3080, loss 3.0144
# Epoch 371, loss_center 1.7041, loss_aux 1.3141, loss 3.0183
# Epoch 372, loss_center 1.7079, loss_aux 1.3037, loss 3.0116
# Epoch 373, loss_center 1.7043, loss_aux 1.3085, loss 3.0129
# Epoch 374, loss_center 1.7087, loss_aux 1.3161, loss 3.0248
# Epoch 375, loss_center 1.7055, loss_aux 1.3126, loss 3.0181
# Epoch 376, loss_center 1.7066, loss_aux 1.3088, loss 3.0153
# Epoch 377, loss_center 1.7049, loss_aux 1.3073, loss 3.0122
# Epoch 378, loss_center 1.7059, loss_aux 1.3116, loss 3.0175
# Epoch 379, loss_center 1.7044, loss_aux 1.3044, loss 3.0088
# Epoch 380, loss_center 1.7102, loss_aux 1.3045, loss 3.0147
# Epoch 381, loss_center 1.7061, loss_aux 1.3336, loss 3.0398
# Epoch 382, loss_center 1.7092, loss_aux 1.3157, loss 3.0249
# Epoch 383, loss_center 1.7045, loss_aux 1.3140, loss 3.0185
# Epoch 384, loss_center 1.7070, loss_aux 1.2998, loss 3.0067
# Epoch 385, loss_center 1.7044, loss_aux 1.3074, loss 3.0118
# Epoch 386, loss_center 1.7043, loss_aux 1.3097, loss 3.0140
# Epoch 387, loss_center 1.7043, loss_aux 1.3125, loss 3.0168
# Epoch 388, loss_center 1.7072, loss_aux 1.3032, loss 3.0104
# Epoch 389, loss_center 1.7058, loss_aux 1.3138, loss 3.0196
# Epoch 390, loss_center 1.7049, loss_aux 1.3039, loss 3.0088
# Epoch 391, loss_center 1.7050, loss_aux 1.3146, loss 3.0196
# Epoch 392, loss_center 1.7118, loss_aux 1.3244, loss 3.0362
# Epoch 393, loss_center 1.7101, loss_aux 1.3100, loss 3.0201
# Epoch 394, loss_center 1.7024, loss_aux 1.3027, loss 3.0051
# Epoch 395, loss_center 1.7041, loss_aux 1.3053, loss 3.0093
# Epoch 396, loss_center 1.7049, loss_aux 1.3000, loss 3.0049
# Epoch 397, loss_center 1.7016, loss_aux 1.3074, loss 3.0091
# Epoch 398, loss_center 1.7076, loss_aux 1.3147, loss 3.0222
# Epoch 399, loss_center 1.7039, loss_aux 1.2980, loss 3.0019
# Epoch 400, loss_center 1.7061, loss_aux 1.3090, loss 3.0151
# Epoch 401, loss_center 1.7064, loss_aux 1.3135, loss 3.0198
# Epoch 402, loss_center 1.7038, loss_aux 1.3069, loss 3.0107
# Epoch 403, loss_center 1.7058, loss_aux 1.3147, loss 3.0206
# Epoch 404, loss_center 1.7048, loss_aux 1.3139, loss 3.0187
# Epoch 405, loss_center 1.7065, loss_aux 1.3169, loss 3.0234
# Epoch 406, loss_center 1.7041, loss_aux 1.3023, loss 3.0065
# Epoch 407, loss_center 1.7055, loss_aux 1.3043, loss 3.0098
# Epoch 408, loss_center 1.7031, loss_aux 1.3021, loss 3.0052
# Epoch 409, loss_center 1.7054, loss_aux 1.3018, loss 3.0072
# Epoch 410, loss_center 1.7050, loss_aux 1.3057, loss 3.0107
# Epoch 411, loss_center 1.7019, loss_aux 1.3012, loss 3.0031
# Epoch 412, loss_center 1.7035, loss_aux 1.2965, loss 3.0000
# Epoch 413, loss_center 1.7054, loss_aux 1.3123, loss 3.0177
# Epoch 414, loss_center 1.7013, loss_aux 1.3034, loss 3.0047
# Epoch 415, loss_center 1.7034, loss_aux 1.3072, loss 3.0106
# Epoch 416, loss_center 1.7015, loss_aux 1.3053, loss 3.0068
# Epoch 417, loss_center 1.7026, loss_aux 1.3002, loss 3.0027
# Epoch 418, loss_center 1.7038, loss_aux 1.3036, loss 3.0074
# Epoch 419, loss_center 1.7020, loss_aux 1.2992, loss 3.0012
# Epoch 420, loss_center 1.7031, loss_aux 1.3113, loss 3.0144
# Epoch 421, loss_center 1.7047, loss_aux 1.3036, loss 3.0083
# Epoch 422, loss_center 1.7080, loss_aux 1.3287, loss 3.0367
# Epoch 423, loss_center 1.7034, loss_aux 1.3153, loss 3.0187
# Epoch 424, loss_center 1.7020, loss_aux 1.3029, loss 3.0049
# Epoch 425, loss_center 1.7076, loss_aux 1.3075, loss 3.0151
# Epoch 426, loss_center 1.7035, loss_aux 1.3036, loss 3.0070
# Epoch 427, loss_center 1.7034, loss_aux 1.3224, loss 3.0258
# Epoch 428, loss_center 1.7013, loss_aux 1.2932, loss 2.9945
# Epoch 429, loss_center 1.7048, loss_aux 1.3118, loss 3.0166
# Epoch 430, loss_center 1.7011, loss_aux 1.3118, loss 3.0129
# Epoch 431, loss_center 1.7030, loss_aux 1.3047, loss 3.0077
# Epoch 432, loss_center 1.7039, loss_aux 1.3168, loss 3.0207
# Epoch 433, loss_center 1.7015, loss_aux 1.3227, loss 3.0242
# Epoch 434, loss_center 1.7025, loss_aux 1.2972, loss 2.9997
# Epoch 435, loss_center 1.7035, loss_aux 1.3063, loss 3.0098
# Epoch 436, loss_center 1.7022, loss_aux 1.3058, loss 3.0079
# Epoch 437, loss_center 1.7036, loss_aux 1.3055, loss 3.0091
# Epoch 438, loss_center 1.7062, loss_aux 1.3021, loss 3.0083
# Epoch 439, loss_center 1.7066, loss_aux 1.3064, loss 3.0130
# Epoch 440, loss_center 1.7047, loss_aux 1.3290, loss 3.0337
# Epoch 441, loss_center 1.7016, loss_aux 1.2996, loss 3.0013
# Epoch 442, loss_center 1.7021, loss_aux 1.3055, loss 3.0076
# Epoch 443, loss_center 1.7030, loss_aux 1.2927, loss 2.9957
# Epoch 444, loss_center 1.7024, loss_aux 1.3093, loss 3.0117
# Epoch 445, loss_center 1.7014, loss_aux 1.3113, loss 3.0126
# Epoch 446, loss_center 1.7059, loss_aux 1.3099, loss 3.0158
# Epoch 447, loss_center 1.7016, loss_aux 1.2968, loss 2.9984
# Epoch 448, loss_center 1.7013, loss_aux 1.2956, loss 2.9969
# Epoch 449, loss_center 1.7009, loss_aux 1.3000, loss 3.0009
# Epoch 450, loss_center 1.7049, loss_aux 1.3017, loss 3.0066
# Epoch 451, loss_center 1.7028, loss_aux 1.3061, loss 3.0089
# Epoch 452, loss_center 1.7018, loss_aux 1.2896, loss 2.9914
# Epoch 453, loss_center 1.7036, loss_aux 1.3022, loss 3.0058
# Epoch 454, loss_center 1.7013, loss_aux 1.3006, loss 3.0019
# Epoch 455, loss_center 1.7028, loss_aux 1.3069, loss 3.0097
# Epoch 456, loss_center 1.7028, loss_aux 1.3056, loss 3.0084
# Epoch 457, loss_center 1.7016, loss_aux 1.2963, loss 2.9978
# Epoch 458, loss_center 1.7019, loss_aux 1.3198, loss 3.0217
# Epoch 459, loss_center 1.7004, loss_aux 1.3043, loss 3.0048
# Epoch 460, loss_center 1.7023, loss_aux 1.2930, loss 2.9954
# Epoch 461, loss_center 1.7016, loss_aux 1.2963, loss 2.9979
# Epoch 462, loss_center 1.7021, loss_aux 1.2920, loss 2.9941
# Epoch 463, loss_center 1.7013, loss_aux 1.2920, loss 2.9933
# Epoch 464, loss_center 1.7000, loss_aux 1.3065, loss 3.0065
# Epoch 465, loss_center 1.7032, loss_aux 1.3068, loss 3.0100
# Epoch 466, loss_center 1.7051, loss_aux 1.3099, loss 3.0150
# Epoch 467, loss_center 1.7015, loss_aux 1.2929, loss 2.9944
# Epoch 468, loss_center 1.7008, loss_aux 1.3026, loss 3.0033
# Epoch 469, loss_center 1.7028, loss_aux 1.3015, loss 3.0043
# Epoch 470, loss_center 1.7025, loss_aux 1.3061, loss 3.0086
# Epoch 471, loss_center 1.6995, loss_aux 1.3029, loss 3.0024
# Epoch 472, loss_center 1.7048, loss_aux 1.3037, loss 3.0085
# Epoch 473, loss_center 1.7038, loss_aux 1.3038, loss 3.0076
# Epoch 474, loss_center 1.7008, loss_aux 1.2992, loss 3.0000
# Epoch 475, loss_center 1.7028, loss_aux 1.2939, loss 2.9966
# Epoch 476, loss_center 1.7006, loss_aux 1.2934, loss 2.9940
# Epoch 477, loss_center 1.7024, loss_aux 1.3065, loss 3.0089
# Epoch 478, loss_center 1.7012, loss_aux 1.3026, loss 3.0039
# Epoch 479, loss_center 1.7009, loss_aux 1.2939, loss 2.9948
# Epoch 480, loss_center 1.7004, loss_aux 1.3024, loss 3.0028
# Epoch 481, loss_center 1.7018, loss_aux 1.3027, loss 3.0045
# Epoch 482, loss_center 1.7019, loss_aux 1.3009, loss 3.0028
# Epoch 483, loss_center 1.7029, loss_aux 1.3041, loss 3.0070
# Epoch 484, loss_center 1.7036, loss_aux 1.3100, loss 3.0136
# Epoch 485, loss_center 1.7035, loss_aux 1.3033, loss 3.0069
# Epoch 486, loss_center 1.6964, loss_aux 1.3052, loss 3.0016
# Epoch 487, loss_center 1.6978, loss_aux 1.2947, loss 2.9925
# Epoch 488, loss_center 1.7045, loss_aux 1.3088, loss 3.0133
# Epoch 489, loss_center 1.6993, loss_aux 1.2976, loss 2.9969
# Epoch 490, loss_center 1.7003, loss_aux 1.3087, loss 3.0090
# Epoch 491, loss_center 1.7008, loss_aux 1.3142, loss 3.0151
# Epoch 492, loss_center 1.7099, loss_aux 1.3382, loss 3.0481
# Epoch 493, loss_center 1.7006, loss_aux 1.3103, loss 3.0110
# Epoch 494, loss_center 1.7063, loss_aux 1.3069, loss 3.0132
# Epoch 495, loss_center 1.7000, loss_aux 1.3074, loss 3.0074
# Epoch 496, loss_center 1.7016, loss_aux 1.3073, loss 3.0089
# Epoch 497, loss_center 1.6994, loss_aux 1.2923, loss 2.9917
# Epoch 498, loss_center 1.7005, loss_aux 1.2926, loss 2.9931
# Epoch 499, loss_center 1.6979, loss_aux 1.3015, loss 2.9994

# %%
torch.save(model.state_dict(), 'model.pt')

# %%
model = Classifier(1, 64, 10)
model.load_state_dict(torch.load('model.pt'))
# Out:
# <All keys matched successfully>

# %%
path = '/n/scratch2/kexinhuang/MGNN_Data/cora/fold1/'
path = '../../MGNN_Local_Data/cora/'

valset = Subgraphs(path, 'val', total_subgraph, info, center_node, nodes_aux, labels_aux)
#testset = Subgraphs(path, mode='test', path_s = 'list_subgraph.pkl', path_l = 'label.pkl')
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
model.eval()
# Convert a list of tuples to two lists
test_X, test_Y, center_nodes, nodes_aux, labels_aux = map(list, zip(*valset))
test_bg = dgl.batch(test_X)
test_Y = torch.tensor(test_Y).float().view(-1, 1)
test_bg.to(device)
test_Y.to(device)
center_nodes = torch.LongTensor(center_nodes).to(device)

probs_Y = torch.softmax(model(test_bg, center_nodes, nodes_aux), 1)
argmax_Y = torch.max(probs_Y, 1)[1].view(-1, 1)
print('Accuracy of argmax predictions on the test set: {:4f}%'.format(
    (test_Y == argmax_Y.detach().cpu().float()).sum().item() / len(test_Y) * 100))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-5387ae74e2ea> in <module>
#       8 model.eval()
#       9 # Convert a list of tuples to two lists
# ---> 10 test_X, test_Y, center_nodes, nodes_aux, labels_aux = map(list, zip(*valset))
#      11 test_bg = dgl.batch(test_X)
#      12 test_Y = torch.tensor(test_Y).float().view(-1, 1)
#
# ValueError: not enough values to unpack (expected 5, got 0)
