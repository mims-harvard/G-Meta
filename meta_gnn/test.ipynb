# %%
# !python sgc.py
# Out:
# /home/kh278/MGNN/meta_gnn/normalization.py:97: RuntimeWarning: divide by zero encountered in power
#   r_inv = np.power(rowsum, -1).flatten()
# Cross Validation: 1
# Cross Validation 1 Train_Label_List: [2, 3, 4, 5]
# Cross Validation 1 Test_Label_List: [0, 1]
# Step: 0 	Meta_Training_Accuracy: [0.49166667 0.49166667 0.55       0.54166667 0.56666667 0.58333333
#  0.6        0.60833333 0.60833333 0.6        0.60833333]
# Cross Validation:1, Step: 0, Meta-Test_Accuracy: [0.5    0.5146 0.524  0.521  0.5205 0.5146 0.5146 0.5156 0.5176 0.5156
#  0.5156]
# Step: 100 	Meta_Training_Accuracy: [0.5        0.60833333 0.65       0.65833333 0.675      0.70833333
#  0.7        0.7        0.7        0.7        0.7       ]
# Cross Validation:1, Step: 100, Meta-Test_Accuracy: [0.5    0.4895 0.492  0.4917 0.4902 0.4902 0.493  0.4937 0.4956 0.4998
#  0.4998]
# Step: 200 	Meta_Training_Accuracy: [0.5        0.25       0.18333333 0.23333333 0.21666667 0.21666667
# ...
