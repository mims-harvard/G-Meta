# %%
# !python ./graphlet_finetune_label/train.py \
        --data_dir ./data/single_graph/BA/META_SETUP_LABEL/ \
        --fold_n 2 \
        --epoch 10 \
        --k_spt 1 \
        --k_qry 6
# Out:
# Namespace(attention_size=32, data_dir='./data/single_graph/BA/META_SETUP_LABEL/', epoch=10, fold_n=2, hidden_dim=32, input_dim=1, k_qry=6, k_spt=1, meta_lr=0.001, n_graphlets=5, n_way=2, task_num=4, update_lr=0.01, update_step=5, update_step_test=10)
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 1042.84it/s]
# There are 1 non-isomorphic graphs
# 100%|███████████████████████████████████████████| 2/2 [00:00<00:00, 1517.48it/s]
# There are 2 non-isomorphic graphs
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 531.08it/s]
# There are 6 non-isomorphic graphs
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 38.92it/s]
# There are 21 non-isomorphic graphs
# There are 30 number of graphlets
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.FloatTensor of size 1x32]
#         (1): Parameter containing: [torch.FloatTensor of size 32]
# ...

# %%
# !python ./graphlet_finetune_label/train.py \
        --data_dir ./data/single_graph/BA/META_SETUP_LABEL/ \
        --fold_n 1 \
        --epoch 10 \
        --k_spt 1 \
        --k_qry 6
# Out:
# Namespace(attention_size=32, data_dir='./data/single_graph/BA/META_SETUP_LABEL/', epoch=10, fold_n=1, hidden_dim=32, input_dim=1, k_qry=6, k_spt=1, meta_lr=0.001, n_graphlets=5, n_way=2, task_num=4, update_lr=0.01, update_step=5, update_step_test=10)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 849.57it/s]
# There are 1 non-isomorphic graphs
# 100%|███████████████████████████████████████████| 2/2 [00:00<00:00, 1502.53it/s]
# There are 2 non-isomorphic graphs
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 480.83it/s]
# There are 6 non-isomorphic graphs
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 37.78it/s]
# There are 21 non-isomorphic graphs
# There are 30 number of graphlets
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.FloatTensor of size 1x32]
#         (1): Parameter containing: [torch.FloatTensor of size 32]
# ...

# %%
# !python ./graphlet_finetune_label/train.py \
        --data_dir ./data/single_graph/BA/META_SETUP_LABEL/ \
        --fold_n 3 \
        --epoch 10 \
        --k_spt 1\
        --k_qry 6
# Out:
# Namespace(attention_size=32, data_dir='./data/single_graph/BA/META_SETUP_LABEL/', epoch=10, fold_n=3, hidden_dim=32, input_dim=1, k_qry=6, k_spt=1, meta_lr=0.001, n_graphlets=5, n_way=2, task_num=4, update_lr=0.01, update_step=5, update_step_test=10)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 872.00it/s]
# There are 1 non-isomorphic graphs
# 100%|███████████████████████████████████████████| 2/2 [00:00<00:00, 1283.64it/s]
# There are 2 non-isomorphic graphs
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 521.37it/s]
# There are 6 non-isomorphic graphs
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 38.45it/s]
# There are 21 non-isomorphic graphs
# There are 30 number of graphlets
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.FloatTensor of size 1x32]
#         (1): Parameter containing: [torch.FloatTensor of size 32]
# ...

# %%
# !python ./graphlet_finetune_label/train.py \
        --data_dir ./data/single_graph/BA/META_SETUP_LABEL/ \
        --fold_n 4 \
        --epoch 10 \
        --k_spt 1\
        --k_qry 6
# Out:
# Namespace(attention_size=32, data_dir='./data/single_graph/BA/META_SETUP_LABEL/', epoch=10, fold_n=4, hidden_dim=32, input_dim=1, k_qry=6, k_spt=1, meta_lr=0.001, n_graphlets=5, n_way=2, task_num=4, update_lr=0.01, update_step=5, update_step_test=10)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 520.58it/s]
# There are 1 non-isomorphic graphs
# 100%|████████████████████████████████████████████| 2/2 [00:00<00:00, 760.39it/s]
# There are 2 non-isomorphic graphs
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 395.85it/s]
# There are 6 non-isomorphic graphs
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 37.98it/s]
# There are 21 non-isomorphic graphs
# There are 30 number of graphlets
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.FloatTensor of size 1x32]
#         (1): Parameter containing: [torch.FloatTensor of size 32]
# ...

# %%
# !python ./graphlet_finetune_label/train.py \
        --data_dir ./data/single_graph/BA/META_SETUP_LABEL/ \
        --fold_n 5 \
        --epoch 10 \
        --k_spt 1\
        --k_qry 6
# Out:
# Namespace(attention_size=32, data_dir='./data/single_graph/BA/META_SETUP_LABEL/', epoch=10, fold_n=5, hidden_dim=32, input_dim=1, k_qry=6, k_spt=1, meta_lr=0.001, n_graphlets=5, n_way=2, task_num=4, update_lr=0.01, update_step=5, update_step_test=10)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 899.29it/s]
# There are 1 non-isomorphic graphs
# 100%|███████████████████████████████████████████| 2/2 [00:00<00:00, 1610.10it/s]
# There are 2 non-isomorphic graphs
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 516.87it/s]
# There are 6 non-isomorphic graphs
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 40.98it/s]
# There are 21 non-isomorphic graphs
# There are 30 number of graphlets
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.FloatTensor of size 1x32]
#         (1): Parameter containing: [torch.FloatTensor of size 32]
# ...

# %%
# !python ./graphlet_meta_label/train.py \
        --data_dir ./data/single_graph/BA/META_SETUP_LABEL/ \
        --fold_n 1 \
        --epoch 10 \
        --k_spt 1\
        --k_qry 6
# Out:
# Namespace(attention_size=32, data_dir='./data/single_graph/BA/META_SETUP_LABEL/', epoch=10, fold_n=1, hidden_dim=32, input_dim=1, k_qry=6, k_spt=1, meta_lr=0.001, n_graphlets=5, n_way=2, no_finetune=True, task_num=4, update_lr=0.01, update_step=5, update_step_test=10)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 575.90it/s]
# There are 1 non-isomorphic graphs
# 100%|████████████████████████████████████████████| 2/2 [00:00<00:00, 867.67it/s]
# There are 2 non-isomorphic graphs
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 394.21it/s]
# There are 6 non-isomorphic graphs
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 39.52it/s]
# There are 21 non-isomorphic graphs
# There are 30 number of graphlets
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.FloatTensor of size 1x32]
#         (1): Parameter containing: [torch.FloatTensor of size 32]
# ...

# %%
# !python ./graphlet_meta_label/train.py \
        --data_dir ./data/single_graph/BA/META_SETUP_LABEL/ \
        --fold_n 2 \
        --epoch 10 \
        --k_spt 1\
        --k_qry 6
# Out:
# Namespace(attention_size=32, data_dir='./data/single_graph/BA/META_SETUP_LABEL/', epoch=10, fold_n=2, hidden_dim=32, input_dim=1, k_qry=6, k_spt=1, meta_lr=0.001, n_graphlets=5, n_way=2, no_finetune=True, task_num=4, update_lr=0.01, update_step=5, update_step_test=10)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 904.14it/s]
# There are 1 non-isomorphic graphs
# 100%|███████████████████████████████████████████| 2/2 [00:00<00:00, 1383.12it/s]
# There are 2 non-isomorphic graphs
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 479.28it/s]
# There are 6 non-isomorphic graphs
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 39.93it/s]
# There are 21 non-isomorphic graphs
# There are 30 number of graphlets
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.FloatTensor of size 1x32]
#         (1): Parameter containing: [torch.FloatTensor of size 32]
# ...

# %%
# !python ./graphlet_meta_label/train.py \
        --data_dir ./data/single_graph/BA/META_SETUP_LABEL/ \
        --fold_n 3 \
        --epoch 10 \
        --k_spt 1\
        --k_qry 6
# Out:
# Namespace(attention_size=32, data_dir='./data/single_graph/BA/META_SETUP_LABEL/', epoch=10, fold_n=3, hidden_dim=32, input_dim=1, k_qry=6, k_spt=1, meta_lr=0.001, n_graphlets=5, n_way=2, no_finetune=True, task_num=4, update_lr=0.01, update_step=5, update_step_test=10)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 868.03it/s]
# There are 1 non-isomorphic graphs
# 100%|███████████████████████████████████████████| 2/2 [00:00<00:00, 1454.08it/s]
# There are 2 non-isomorphic graphs
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 509.62it/s]
# There are 6 non-isomorphic graphs
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 38.92it/s]
# There are 21 non-isomorphic graphs
# There are 30 number of graphlets
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.FloatTensor of size 1x32]
#         (1): Parameter containing: [torch.FloatTensor of size 32]
# ...

# %%
# !python ./graphlet_meta_label/train.py \
        --data_dir ./data/single_graph/BA/META_SETUP_LABEL/ \
        --fold_n 4 \
        --epoch 10 \
        --k_spt 1\
        --k_qry 6
# Out:
# Namespace(attention_size=32, data_dir='./data/single_graph/BA/META_SETUP_LABEL/', epoch=10, fold_n=4, hidden_dim=32, input_dim=1, k_qry=6, k_spt=1, meta_lr=0.001, n_graphlets=5, n_way=2, no_finetune=True, task_num=4, update_lr=0.01, update_step=5, update_step_test=10)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 808.31it/s]
# There are 1 non-isomorphic graphs
# 100%|███████████████████████████████████████████| 2/2 [00:00<00:00, 1150.70it/s]
# There are 2 non-isomorphic graphs
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 443.41it/s]
# There are 6 non-isomorphic graphs
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 40.06it/s]
# There are 21 non-isomorphic graphs
# There are 30 number of graphlets
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.FloatTensor of size 1x32]
#         (1): Parameter containing: [torch.FloatTensor of size 32]
# ...

# %%
# !python ./graphlet_meta_label/train.py \
        --data_dir ./data/single_graph/BA/META_SETUP_LABEL/ \
        --fold_n 5 \
        --epoch 10 \
        --k_spt 1\
        --k_qry 6
# Out:
# Namespace(attention_size=32, data_dir='./data/single_graph/BA/META_SETUP_LABEL/', epoch=10, fold_n=5, hidden_dim=32, input_dim=1, k_qry=6, k_spt=1, meta_lr=0.001, n_graphlets=5, n_way=2, no_finetune=True, task_num=4, update_lr=0.01, update_step=5, update_step_test=10)
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 1058.10it/s]
# There are 1 non-isomorphic graphs
# 100%|███████████████████████████████████████████| 2/2 [00:00<00:00, 1626.01it/s]
# There are 2 non-isomorphic graphs
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 542.37it/s]
# There are 6 non-isomorphic graphs
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 38.44it/s]
# There are 21 non-isomorphic graphs
# There are 30 number of graphlets
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.FloatTensor of size 1x32]
#         (1): Parameter containing: [torch.FloatTensor of size 32]
# ...

# %%
# !python ./graphlet_meta_label/train.py \
        --data_dir ./data/single_graph/BA/META_SETUP_LABEL/ \
        --fold_n 1 \
        --epoch 10 \
        --k_spt 1 \
        --no_finetune False \
        --update_step_test 30 \
        --k_qry 6
# Out:
# Namespace(attention_size=32, data_dir='./data/single_graph/BA/META_SETUP_LABEL/', epoch=10, fold_n=1, hidden_dim=32, input_dim=1, k_qry=6, k_spt=1, meta_lr=0.001, n_graphlets=5, n_way=2, no_finetune='False', task_num=4, update_lr=0.01, update_step=5, update_step_test=30)
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 1030.04it/s]
# There are 1 non-isomorphic graphs
# 100%|███████████████████████████████████████████| 2/2 [00:00<00:00, 1726.76it/s]
# There are 2 non-isomorphic graphs
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 539.79it/s]
# There are 6 non-isomorphic graphs
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 39.06it/s]
# There are 21 non-isomorphic graphs
# There are 30 number of graphlets
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.FloatTensor of size 1x32]
#         (1): Parameter containing: [torch.FloatTensor of size 32]
# ...

# %%
# !python ./graphlet_meta_label/train.py \
        --data_dir ./data/single_graph/BA/META_SETUP_LABEL/ \
        --fold_n 2 \
        --epoch 10 \
        --k_spt 1 \
        --no_finetune False \
        --update_step_test 30 \
        --k_qry 6
# Out:
# Namespace(attention_size=32, data_dir='./data/single_graph/BA/META_SETUP_LABEL/', epoch=10, fold_n=2, hidden_dim=32, input_dim=1, k_qry=6, k_spt=1, meta_lr=0.001, n_graphlets=5, n_way=2, no_finetune='False', task_num=4, update_lr=0.01, update_step=5, update_step_test=30)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 876.55it/s]
# There are 1 non-isomorphic graphs
# 100%|███████████████████████████████████████████| 2/2 [00:00<00:00, 1404.66it/s]
# There are 2 non-isomorphic graphs
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 375.77it/s]
# There are 6 non-isomorphic graphs
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 39.81it/s]
# There are 21 non-isomorphic graphs
# There are 30 number of graphlets
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.FloatTensor of size 1x32]
#         (1): Parameter containing: [torch.FloatTensor of size 32]
# ...

# %%
# !python ./graphlet_meta_label/train.py \
        --data_dir ./data/single_graph/BA/META_SETUP_LABEL/ \
        --fold_n 3 \
        --epoch 10 \
        --k_spt 1 \
        --no_finetune False \
        --update_step_test 30 \
        --k_qry 6
# Out:
# Namespace(attention_size=32, data_dir='./data/single_graph/BA/META_SETUP_LABEL/', epoch=10, fold_n=3, hidden_dim=32, input_dim=1, k_qry=6, k_spt=1, meta_lr=0.001, n_graphlets=5, n_way=2, no_finetune='False', task_num=4, update_lr=0.01, update_step=5, update_step_test=30)
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 1029.78it/s]
# There are 1 non-isomorphic graphs
# 100%|███████████████████████████████████████████| 2/2 [00:00<00:00, 1588.45it/s]
# There are 2 non-isomorphic graphs
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 347.49it/s]
# There are 6 non-isomorphic graphs
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 38.87it/s]
# There are 21 non-isomorphic graphs
# There are 30 number of graphlets
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.FloatTensor of size 1x32]
#         (1): Parameter containing: [torch.FloatTensor of size 32]
# ...

# %%
# !python ./graphlet_meta_label/train.py \
        --data_dir ./data/single_graph/BA/META_SETUP_LABEL/ \
        --fold_n 4 \
        --epoch 10 \
        --k_spt 1 \
        --no_finetune False \
        --update_step_test 30 \
        --k_qry 6
# Out:
# Namespace(attention_size=32, data_dir='./data/single_graph/BA/META_SETUP_LABEL/', epoch=10, fold_n=4, hidden_dim=32, input_dim=1, k_qry=6, k_spt=1, meta_lr=0.001, n_graphlets=5, n_way=2, no_finetune='False', task_num=4, update_lr=0.01, update_step=5, update_step_test=30)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 160.82it/s]
# There are 1 non-isomorphic graphs
# 100%|███████████████████████████████████████████| 2/2 [00:00<00:00, 1481.30it/s]
# There are 2 non-isomorphic graphs
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 513.99it/s]
# There are 6 non-isomorphic graphs
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 37.25it/s]
# There are 21 non-isomorphic graphs
# There are 30 number of graphlets
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.FloatTensor of size 1x32]
#         (1): Parameter containing: [torch.FloatTensor of size 32]
# ...

# %%
# !python ./graphlet_meta_label/train.py \
        --data_dir ./data/single_graph/BA/META_SETUP_LABEL/ \
        --fold_n 5 \
        --epoch 10 \
        --k_spt 1 \
        --no_finetune False \
        --k_qry 6
# Out:
# Namespace(attention_size=32, data_dir='./data/single_graph/BA/META_SETUP_LABEL/', epoch=10, fold_n=5, hidden_dim=32, input_dim=1, k_qry=6, k_spt=1, meta_lr=0.001, n_graphlets=5, n_way=2, no_finetune='False', task_num=4, update_lr=0.01, update_step=5, update_step_test=10)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 144.49it/s]
# There are 1 non-isomorphic graphs
# 100%|███████████████████████████████████████████| 2/2 [00:00<00:00, 1411.51it/s]
# There are 2 non-isomorphic graphs
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 504.49it/s]
# There are 6 non-isomorphic graphs
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 35.61it/s]
# There are 21 non-isomorphic graphs
# There are 30 number of graphlets
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.FloatTensor of size 1x32]
#         (1): Parameter containing: [torch.FloatTensor of size 32]
# ...

# %%
# !python ./graphlet_ProtoMAML_label/train.py \
        --data_dir ./data/single_graph/BA/META_SETUP_LABEL/ \
        --fold_n 1 \
        --k_spt 1 \
        --k_qry 6 \
        --meta_lr 1e-2 \
        --update_lr 0.03 \
        --epoch 10
# Out:
# Namespace(attention_size=32, data_dir='./data/single_graph/BA/META_SETUP_LABEL/', epoch=10, fold_n=1, hidden_dim=32, input_dim=1, k_qry=6, k_spt=1, meta_lr=0.01, n_graphlets=5, n_way=2, no_finetune=True, task_num=4, update_lr=0.03, update_step=5, update_step_test=10)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 182.25it/s]
# There are 1 non-isomorphic graphs
# 100%|████████████████████████████████████████████| 2/2 [00:00<00:00, 934.66it/s]
# There are 2 non-isomorphic graphs
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 369.57it/s]
# There are 6 non-isomorphic graphs
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 36.98it/s]
# There are 21 non-isomorphic graphs
# There are 30 number of graphlets
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.FloatTensor of size 1x32]
#         (1): Parameter containing: [torch.FloatTensor of size 32]
# ...

# %%
# !python ./graphlet_ProtoMAML_label/train.py \
        --data_dir ./data/single_graph/BA/META_SETUP_LABEL/ \
        --fold_n 2 \
        --k_spt 1 \
        --k_qry 6 \
        --meta_lr 1e-2 \
        --update_lr 0.03 \
        --epoch 10
# Out:
# Namespace(attention_size=32, data_dir='./data/single_graph/BA/META_SETUP_LABEL/', epoch=10, fold_n=2, hidden_dim=32, input_dim=1, k_qry=6, k_spt=1, meta_lr=0.01, n_graphlets=5, n_way=2, no_finetune=True, task_num=4, update_lr=0.03, update_step=5, update_step_test=10)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 590.33it/s]
# There are 1 non-isomorphic graphs
# 100%|████████████████████████████████████████████| 2/2 [00:00<00:00, 981.81it/s]
# There are 2 non-isomorphic graphs
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 397.06it/s]
# There are 6 non-isomorphic graphs
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 37.38it/s]
# There are 21 non-isomorphic graphs
# There are 30 number of graphlets
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.FloatTensor of size 1x32]
#         (1): Parameter containing: [torch.FloatTensor of size 32]
# ...

# %%
# !python ./graphlet_ProtoMAML_label/train.py \
        --data_dir ./data/single_graph/BA/META_SETUP_LABEL/ \
        --fold_n 3 \
        --k_spt 1 \
        --k_qry 6 \
        --meta_lr 1e-2 \
        --update_lr 0.03 \
        --epoch 10
# Out:
# Namespace(attention_size=32, data_dir='./data/single_graph/BA/META_SETUP_LABEL/', epoch=10, fold_n=3, hidden_dim=32, input_dim=1, k_qry=6, k_spt=1, meta_lr=0.01, n_graphlets=5, n_way=2, no_finetune=True, task_num=4, update_lr=0.03, update_step=5, update_step_test=10)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 705.28it/s]
# There are 1 non-isomorphic graphs
# 100%|███████████████████████████████████████████| 2/2 [00:00<00:00, 1272.54it/s]
# There are 2 non-isomorphic graphs
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 406.01it/s]
# There are 6 non-isomorphic graphs
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 38.01it/s]
# There are 21 non-isomorphic graphs
# There are 30 number of graphlets
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.FloatTensor of size 1x32]
#         (1): Parameter containing: [torch.FloatTensor of size 32]
# ...

# %%
# !python ./graphlet_ProtoMAML_label/train.py \
        --data_dir ./data/single_graph/BA/META_SETUP_LABEL/ \
        --fold_n 4 \
        --k_spt 1 \
        --k_qry 6 \
        --meta_lr 1e-2 \
        --update_lr 0.03 \
        --epoch 10
# Out:
# Namespace(attention_size=32, data_dir='./data/single_graph/BA/META_SETUP_LABEL/', epoch=10, fold_n=4, hidden_dim=32, input_dim=1, k_qry=6, k_spt=1, meta_lr=0.01, n_graphlets=5, n_way=2, no_finetune=True, task_num=4, update_lr=0.03, update_step=5, update_step_test=10)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 701.27it/s]
# There are 1 non-isomorphic graphs
# 100%|███████████████████████████████████████████| 2/2 [00:00<00:00, 1286.99it/s]
# There are 2 non-isomorphic graphs
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 432.66it/s]
# There are 6 non-isomorphic graphs
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 39.51it/s]
# There are 21 non-isomorphic graphs
# There are 30 number of graphlets
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.FloatTensor of size 1x32]
#         (1): Parameter containing: [torch.FloatTensor of size 32]
# ...

# %%
# !python ./graphlet_ProtoMAML_label/train.py \
        --data_dir ./data/single_graph/BA/META_SETUP_LABEL/ \
        --fold_n 5 \
        --k_spt 1 \
        --k_qry 6 \
        --meta_lr 1e-2 \
        --update_lr 0.03 \
        --epoch 10
# Out:
# Namespace(attention_size=32, data_dir='./data/single_graph/BA/META_SETUP_LABEL/', epoch=10, fold_n=5, hidden_dim=32, input_dim=1, k_qry=6, k_spt=1, meta_lr=0.01, n_graphlets=5, n_way=2, no_finetune=True, task_num=4, update_lr=0.03, update_step=5, update_step_test=10)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 861.25it/s]
# There are 1 non-isomorphic graphs
# 100%|███████████████████████████████████████████| 2/2 [00:00<00:00, 1727.12it/s]
# There are 2 non-isomorphic graphs
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 509.62it/s]
# There are 6 non-isomorphic graphs
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 39.02it/s]
# There are 21 non-isomorphic graphs
# There are 30 number of graphlets
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.FloatTensor of size 1x32]
#         (1): Parameter containing: [torch.FloatTensor of size 32]
# ...
