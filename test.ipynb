# %%
# !python G-Meta/train.py --data_dir DATA_PATH/G-Meta_Data/arxiv/ \
                            --epoch 10 \
                            --task_setup Disjoint \
                            --k_spt 3 \
                            --k_qry 24 \
                            --n_way 3 \
                            --update_step 10 \
                            --update_lr 0.01 \
                            --num_workers 0 \
                            --train_result_report_steps 200 \
                            --hidden_dim 256 \
                            --update_step_test 20 \
                            --task_num 32 \
                            --batchsz 10000
# Out:
# Using backend: pytorch
# Namespace(attention_size=32, batchsz=10000, data_dir='/n/scratch3/users/k/kh278/G-Meta_Data/arxiv/', epoch=10, h=2, hidden_dim=256, input_dim=1, k_qry=24, k_spt=3, link_pred_mode='False', meta_lr=0.001, method='G-Meta', n_way=3, no_finetune=True, num_workers=0, sample_nodes=1000, task_mode='False', task_n=1, task_num=32, task_setup='Disjoint', train_result_report_steps=200, update_lr=0.01, update_step=10, update_step_test=20, val_result_report_steps=100)
# There are 40 classes
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.cuda.FloatTensor of size 128x256 (GPU 0)]
#         (1): Parameter containing: [torch.cuda.FloatTensor of size 256 (GPU 0)]
#         (2): Parameter containing: [torch.cuda.FloatTensor of size 256x256 (GPU 0)]
#         (3): Parameter containing: [torch.cuda.FloatTensor of size 256 (GPU 0)]
#         (4): Parameter containing: [torch.cuda.FloatTensor of size 3x256 (GPU 0)]
# ...

# %%
# !python G-Meta/train.py --data_dir DATA_PATH/G-Meta_Data/tissue_PPI/ \
                            --epoch 15 \
                            --task_setup Shared \
                            --task_mode True \
                            --task_n 4 \
                            --k_qry 10 \
                            --k_spt 3 \
                            --update_lr 0.01 \
                            --update_step 10 \
                            --meta_lr 5e-3 \
                            --num_workers 0 \
                            --train_result_report_steps 200 \
                            --hidden_dim 128 \
                            --task_num 4 \
                            --batchsz 1000
# Out:
# Using backend: pytorch
# Namespace(attention_size=32, batchsz=1000, data_dir='/n/scratch3/users/k/kh278/G-Meta_Data/tissue_PPI/', epoch=15, h=2, hidden_dim=128, input_dim=1, k_qry=10, k_spt=3, link_pred_mode='False', meta_lr=0.005, method='G-Meta', n_way=3, no_finetune=True, num_workers=0, sample_nodes=1000, task_mode='True', task_n=4, task_num=4, task_setup='Shared', train_result_report_steps=200, update_lr=0.01, update_step=10, update_step_test=10, val_result_report_steps=100)
# There are 2 classes
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.cuda.FloatTensor of size 50x128 (GPU 0)]
#         (1): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (2): Parameter containing: [torch.cuda.FloatTensor of size 128x128 (GPU 0)]
#         (3): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (4): Parameter containing: [torch.cuda.FloatTensor of size 2x128 (GPU 0)]
# ...

# %%
# !python G-Meta/train.py --data_dir DATA_PATH/G-Meta_Data/fold_PPI/ \
                            --epoch 5 \
                            --task_setup Disjoint \
                            --k_qry 24 \
                            --k_spt 3 \
                            --n_way 3 \
                            --update_lr 0.005 \
                            --meta_lr 1e-3 \
                            --num_workers 0 \
                            --train_result_report_steps 100 \
                            --hidden_dim 128 \
                            --update_step_test 20 \
                            --task_num 16 \
                            --batchsz 4000
# Out:
# Using backend: pytorch
# Namespace(attention_size=32, batchsz=4000, data_dir='/n/scratch3/users/k/kh278/G-Meta_Data/fold_PPI/', epoch=5, h=2, hidden_dim=128, input_dim=1, k_qry=24, k_spt=3, link_pred_mode='False', meta_lr=0.001, method='G-Meta', n_way=3, no_finetune=True, num_workers=0, sample_nodes=1000, task_mode='False', task_n=1, task_num=16, task_setup='Disjoint', train_result_report_steps=100, update_lr=0.005, update_step=5, update_step_test=20, val_result_report_steps=100)
# There are 30 classes
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.cuda.FloatTensor of size 512x128 (GPU 0)]
#         (1): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (2): Parameter containing: [torch.cuda.FloatTensor of size 128x128 (GPU 0)]
#         (3): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (4): Parameter containing: [torch.cuda.FloatTensor of size 3x128 (GPU 0)]
# ...

# %%
# !python G-Meta/train.py --data_dir DATA_PATH/G-Meta_Data/FirstMM_DB/ \
                            --epoch 15 \
                            --task_setup Shared \
                            --k_qry 32 \
                            --k_spt 16 \
                            --n_way 2 \
                            --update_lr 0.01 \
                            --update_step 10 \
                            --meta_lr 5e-4 \
                            --num_workers 0 \
                            --train_result_report_steps 200 \
                            --hidden_dim 128 \
                            --update_step_test 20 \
                            --task_num 8 \
                            --batchsz 1500 \
                            --link_pred_mod True
# Out:
# Using backend: pytorch
# Namespace(attention_size=32, batchsz=1500, data_dir='/n/scratch3/users/k/kh278/G-Meta_Data/FirstMM_DB/', epoch=15, h=2, hidden_dim=128, input_dim=1, k_qry=32, k_spt=16, link_pred_mode='True', meta_lr=0.0005, method='G-Meta', n_way=2, no_finetune=True, num_workers=0, sample_nodes=1000, task_mode='False', task_n=1, task_num=8, task_setup='Shared', train_result_report_steps=200, update_lr=0.01, update_step=10, update_step_test=20, val_result_report_steps=100)
# There are 2 classes
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.cuda.FloatTensor of size 5x128 (GPU 0)]
#         (1): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (2): Parameter containing: [torch.cuda.FloatTensor of size 128x128 (GPU 0)]
#         (3): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (4): Parameter containing: [torch.cuda.FloatTensor of size 2x256 (GPU 0)]
# ...

# %%
# !python G-Meta/train.py --data_dir DATA_PATH/G-Meta_Data/tree-of-life/ \
                            --epoch 15 \
                            --task_setup Shared \
                            --k_qry 16 \
                            --k_spt 16 \
                            --n_way 2 \
                            --update_lr 0.005 \
                            --update_step 10 \
                            --meta_lr 0.0005 \
                            --num_workers 0 \
                            --train_result_report_steps 200 \
                            --hidden_dim 256 \
                            --update_step_test 20 \
                            --task_num 8 \
                            --batchsz 5000 \
                            --link_pred_mod True
# Out:
# Using backend: pytorch
# Namespace(attention_size=32, batchsz=5000, data_dir='/n/scratch3/users/k/kh278/G-Meta_Data/tree-of-life/', epoch=15, h=2, hidden_dim=256, input_dim=1, k_qry=16, k_spt=16, link_pred_mode='True', meta_lr=0.0005, method='G-Meta', n_way=2, no_finetune=True, num_workers=0, sample_nodes=1000, task_mode='False', task_n=1, task_num=8, task_setup='Shared', train_result_report_steps=200, update_lr=0.005, update_step=10, update_step_test=20, val_result_report_steps=100)
# There are 2 classes
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.cuda.FloatTensor of size 1x256 (GPU 0)]
#         (1): Parameter containing: [torch.cuda.FloatTensor of size 256 (GPU 0)]
#         (2): Parameter containing: [torch.cuda.FloatTensor of size 256x256 (GPU 0)]
#         (3): Parameter containing: [torch.cuda.FloatTensor of size 256 (GPU 0)]
#         (4): Parameter containing: [torch.cuda.FloatTensor of size 2x512 (GPU 0)]
# ...
