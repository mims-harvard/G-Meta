# %% [markdown]
# # Example I: Disjoint Single Label

# %%
import time

# %%
s = time.time()
# !python train.py --data_dir /n/scratch2/kexinhuang/MGNN_Data/arxiv/ \
                            --epoch 1 \
                            --task_setup Disjoint \
                            --method ProtoMAML \
                            --fold_n 2 \
                            --k_qry 24 \
                            --k_spt 3 \
                            --n_way 3 \
                            --update_lr 0.01 \
                            --num_workers 0 \
                            --train_result_report_steps 5 \
                            --val_result_report_steps 100 \
                            --hidden_dim 128 \
                            --update_step_test 20 \
                            --task_num 32 \
                            --batchsz 10000 
print((time.time() - s)/60)
# Out:
# Using backend: pytorch
# Namespace(attention_size=32, batchsz=10000, data_dir='/n/scratch2/kexinhuang/MGNN_Data/arxiv/', epoch=1, fold_n=2, graphlets=False, hidden_dim=128, input_dim=1, k_qry=24, k_spt=3, meta_lr=0.001, method='ProtoMAML', n_graphlets=5, n_way=3, no_finetune=True, num_workers=0, task_mode='False', task_n=1, task_num=32, task_setup='Disjoint', train_result_report_steps=5, update_lr=0.01, update_step=5, update_step_test=20, val_result_report_steps=100)
# there are 40 classes
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.cuda.FloatTensor of size 128x128 (GPU 0)]
#         (1): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (2): Parameter containing: [torch.cuda.FloatTensor of size 128x128 (GPU 0)]
#         (3): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (4): Parameter containing: [torch.cuda.FloatTensor of size 3x128 (GPU 0)]
# ...

# %%
# !python train.py --data_dir /n/scratch2/kexinhuang/MGNN_Data/tissue_PPI/ \
                            --epoch 15 \
                            --task_setup Shared \
                            --method ProtoMAML \
                            --fold_n 1 \
                            --task_mode True \
                            --task_n 2 \
                            --k_qry 10 \
                            --k_spt 5 \
                            --update_lr 0.01 \
                            --meta_lr 3e-3 \
                            --num_workers 0 \
                            --train_result_report_steps 30 \
                            --val_result_report_steps 200 \
                            --hidden_dim 128 \
                            --task_num 4 \
                            --batchsz 1000
# Out:
# Using backend: pytorch
# Namespace(attention_size=32, batchsz=1000, data_dir='/n/scratch2/kexinhuang/MGNN_Data/tissue_PPI/', epoch=15, fold_n=1, graphlets=False, hidden_dim=128, input_dim=1, k_qry=10, k_spt=5, meta_lr=0.003, method='ProtoMAML', n_graphlets=5, n_way=2, no_finetune=True, num_workers=0, task_mode='True', task_n=2, task_num=4, task_setup='Shared', train_result_report_steps=30, update_lr=0.01, update_step=5, update_step_test=10, val_result_report_steps=200)
# there are 2 classes
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.cuda.FloatTensor of size 50x128 (GPU 0)]
#         (1): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (2): Parameter containing: [torch.cuda.FloatTensor of size 128x128 (GPU 0)]
#         (3): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (4): Parameter containing: [torch.cuda.FloatTensor of size 2x128 (GPU 0)]
# ...

# %%
# !python train.py --data_dir /n/scratch2/kexinhuang/MGNN_Data/fold_PPI/ \
                            --epoch 5 \
                            --task_setup Disjoint \
                            --method ProtoMAML \
                            --fold_n 1 \
                            --k_qry 24 \
                            --k_spt 3 \
                            --n_way 3 \
                            --update_lr 0.005 \
                            --meta_lr 1e-3 \
                            --num_workers 0 \
                            --train_result_report_steps 10 \
                            --val_result_report_steps 100 \
                            --hidden_dim 128 \
                            --update_step_test 20 \
                            --task_num 16 \
                            --batchsz 4000
# Out:
# Using backend: pytorch
# Namespace(attention_size=32, batchsz=4000, data_dir='/n/scratch2/kexinhuang/MGNN_Data/fold_PPI/', epoch=5, fold_n=1, graphlets=False, hidden_dim=128, input_dim=1, k_qry=24, k_spt=3, meta_lr=0.001, method='ProtoMAML', n_graphlets=5, n_way=3, no_finetune=True, num_workers=0, task_mode='False', task_n=1, task_num=16, task_setup='Disjoint', train_result_report_steps=10, update_lr=0.005, update_step=5, update_step_test=20, val_result_report_steps=100)
# there are 30 classes
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.cuda.FloatTensor of size 512x128 (GPU 0)]
#         (1): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (2): Parameter containing: [torch.cuda.FloatTensor of size 128x128 (GPU 0)]
#         (3): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (4): Parameter containing: [torch.cuda.FloatTensor of size 3x128 (GPU 0)]
# ...

# %%
# !python train.py --data_dir /n/scratch2/kexinhuang/MGNN_Data/fold_PPI/ \
                            --epoch 5 \
                            --task_setup Disjoint \
                            --method ProtoMAML \
                            --fold_n 1 \
                            --k_qry 24 \
                            --k_spt 3 \
                            --n_way 3 \
                            --update_lr 0.005 \
                            --meta_lr 3e-3 \
                            --num_workers 0 \
                            --train_result_report_steps 10 \
                            --val_result_report_steps 100 \
                            --hidden_dim 128 \
                            --update_step_test 20 \
                            --task_num 4 \
                            --batchsz 4000
# Out:
# Using backend: pytorch
# Namespace(attention_size=32, batchsz=4000, data_dir='/n/scratch2/kexinhuang/MGNN_Data/fold_PPI/', epoch=5, fold_n=1, graphlets=False, hidden_dim=128, input_dim=1, k_qry=24, k_spt=3, meta_lr=0.003, method='ProtoMAML', n_graphlets=5, n_way=3, no_finetune=True, num_workers=0, task_mode='False', task_n=1, task_num=4, task_setup='Disjoint', train_result_report_steps=10, update_lr=0.005, update_step=5, update_step_test=20, val_result_report_steps=100)
# there are 30 classes
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.cuda.FloatTensor of size 512x128 (GPU 0)]
#         (1): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (2): Parameter containing: [torch.cuda.FloatTensor of size 128x128 (GPU 0)]
#         (3): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (4): Parameter containing: [torch.cuda.FloatTensor of size 3x128 (GPU 0)]
# ...

# %% [markdown]
# # Link Prediction

# %%
# !python train.py --data_dir /n/scratch2/kexinhuang/MGNN_Data/FirstMM_DB/ \
                            --epoch 15 \
                            --task_setup Shared \
                            --method ProtoMAML \
                            --fold_n 1 \
                            --k_qry 32 \
                            --k_spt 64 \
                            --n_way 2 \
                            --update_lr 0.01 \
                            --update_step 10 \
                            --meta_lr 5e-4 \
                            --num_workers 0 \
                            --train_result_report_steps 10 \
                            --val_result_report_steps 100 \
                            --hidden_dim 128 \
                            --update_step_test 20 \
                            --task_num 8 \
                            --batchsz 1000 \
                            --link_pred_mod True
# Out:
# Using backend: pytorch
# Namespace(attention_size=32, batchsz=1000, data_dir='/n/scratch2/kexinhuang/MGNN_Data/FirstMM_DB/', epoch=15, fold_n=1, graphlets=False, hidden_dim=128, input_dim=1, k_qry=32, k_spt=64, link_pred_mode='True', meta_lr=0.0005, method='ProtoMAML', n_graphlets=5, n_way=2, no_finetune=True, num_workers=0, task_mode='False', task_n=1, task_num=8, task_setup='Shared', train_result_report_steps=10, update_lr=0.01, update_step=10, update_step_test=20, val_result_report_steps=100)
# there are 2 classes
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.cuda.FloatTensor of size 5x128 (GPU 0)]
#         (1): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (2): Parameter containing: [torch.cuda.FloatTensor of size 128x128 (GPU 0)]
#         (3): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
# ...

# %%
# !python train.py --data_dir /n/scratch2/kexinhuang/MGNN_Data/FirstMM_DB/ \
                            --epoch 15 \
                            --task_setup Shared \
                            --method ProtoMAML \
                            --fold_n 1 \
                            --k_qry 32 \
                            --k_spt 64 \
                            --n_way 2 \
                            --update_lr 0.01 \
                            --update_step 10 \
                            --meta_lr 5e-4 \
                            --num_workers 0 \
                            --train_result_report_steps 10 \
                            --val_result_report_steps 100 \
                            --hidden_dim 128 \
                            --update_step_test 20 \
                            --task_num 8 \
                            --batchsz 1000 \
                            --link_pred_mod True
# Out:
# Using backend: pytorch
# Namespace(attention_size=32, batchsz=1000, data_dir='/n/scratch2/kexinhuang/MGNN_Data/FirstMM_DB/', epoch=15, fold_n=1, graphlets=False, hidden_dim=128, input_dim=1, k_qry=32, k_spt=64, link_pred_mode='True', meta_lr=0.0005, method='ProtoMAML', n_graphlets=5, n_way=2, no_finetune=True, num_workers=0, task_mode='False', task_n=1, task_num=8, task_setup='Shared', train_result_report_steps=10, update_lr=0.01, update_step=10, update_step_test=20, val_result_report_steps=100)
# there are 2 classes
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.cuda.FloatTensor of size 5x128 (GPU 0)]
#         (1): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (2): Parameter containing: [torch.cuda.FloatTensor of size 128x128 (GPU 0)]
#         (3): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
# ...

# %%
# !python train.py --data_dir /n/scratch2/kexinhuang/MGNN_Data/FirstMM_DB/ \
                            --epoch 15 \
                            --task_setup Shared \
                            --method MAML \
                            --fold_n 1 \
                            --k_qry 32 \
                            --k_spt 64 \
                            --n_way 2 \
                            --update_lr 0.01 \
                            --update_step 10 \
                            --meta_lr 5e-4 \
                            --num_workers 0 \
                            --train_result_report_steps 10 \
                            --val_result_report_steps 100 \
                            --hidden_dim 128 \
                            --update_step_test 20 \
                            --task_num 8 \
                            --batchsz 1000 \
                            --link_pred_mod True
# Out:
# Using backend: pytorch
# Namespace(attention_size=32, batchsz=1000, data_dir='/n/scratch2/kexinhuang/MGNN_Data/FirstMM_DB/', epoch=15, fold_n=1, graphlets=False, hidden_dim=128, input_dim=1, k_qry=32, k_spt=64, link_pred_mode='True', meta_lr=0.0005, method='MAML', n_graphlets=5, n_way=2, no_finetune=True, num_workers=0, task_mode='False', task_n=1, task_num=8, task_setup='Shared', train_result_report_steps=10, update_lr=0.01, update_step=10, update_step_test=20, val_result_report_steps=100)
# there are 2 classes
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.cuda.FloatTensor of size 5x128 (GPU 0)]
#         (1): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (2): Parameter containing: [torch.cuda.FloatTensor of size 128x128 (GPU 0)]
#         (3): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (4): Parameter containing: [torch.cuda.FloatTensor of size 2x256 (GPU 0)]
# ...

# %%
# !python train.py --data_dir /n/scratch2/kexinhuang/MGNN_Data/FirstMM_DB/ \
                            --epoch 15 \
                            --task_setup Shared \
                            --method ProtoMAML \
                            --fold_n 1 \
                            --k_qry 32 \
                            --k_spt 64 \
                            --n_way 2 \
                            --update_lr 0.01 \
                            --update_step 10 \
                            --meta_lr 5e-4 \
                            --num_workers 0 \
                            --train_result_report_steps 10 \
                            --val_result_report_steps 100 \
                            --hidden_dim 128 \
                            --update_step_test 20 \
                            --task_num 8 \
                            --batchsz 1000 \
                            --link_pred_mod True
# Out:
# Using backend: pytorch
# Namespace(attention_size=32, batchsz=1000, data_dir='/n/scratch2/kexinhuang/MGNN_Data/FirstMM_DB/', epoch=15, fold_n=3, graphlets=False, hidden_dim=128, input_dim=1, k_qry=32, k_spt=64, link_pred_mode='True', meta_lr=0.0005, method='ProtoMAML', n_graphlets=5, n_way=2, no_finetune=True, num_workers=0, task_mode='False', task_n=1, task_num=8, task_setup='Shared', train_result_report_steps=10, update_lr=0.01, update_step=10, update_step_test=20, val_result_report_steps=100)
# there are 2 classes
# Meta(
#   (net): Classifier(
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.cuda.FloatTensor of size 5x128 (GPU 0)]
#         (1): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (2): Parameter containing: [torch.cuda.FloatTensor of size 128x128 (GPU 0)]
#         (3): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
# ...
