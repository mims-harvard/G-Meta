# %%
# !python sgc.py --epoch 10000
# Out:
# True
# Cross Validation: 1
# Cross Validation 1 Train_Label_List: [2, 3, 4]
# Cross Validation 1 Test_Label_List: [0, 1]
# Step: 0 	Meta_Training_Accuracy: [0.475      0.48333333 0.5        0.475      0.475      0.475
#  0.48333333 0.48333333 0.48333333 0.48333333 0.48333333]
# Cross Validation:1, Step: 0, Meta-Test_Accuracy: [0.5    0.507  0.507  0.509  0.51   0.5093 0.5093 0.51   0.5103 0.51
#  0.5107]
# Step: 100 	Meta_Training_Accuracy: [0.5        0.325      0.275      0.275      0.275      0.275
#  0.28333333 0.28333333 0.28333333 0.28333333 0.275     ]
# Cross Validation:1, Step: 100, Meta-Test_Accuracy: [0.5    0.501  0.5054 0.505  0.5054 0.5063 0.5083 0.509  0.508  0.5073
#  0.508 ]
# Step: 200 	Meta_Training_Accuracy: [0.50833333 0.575      0.63333333 0.6        0.58333333 0.575
#  0.58333333 0.58333333 0.58333333 0.58333333 0.58333333]
# Cross Validation:1, Step: 200, Meta-Test_Accuracy: [0.4998 0.503  0.4937 0.494  0.495  0.4966 0.4973 0.4983 0.497  0.4966
#  0.4985]
# ...
